# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:

    '''
    Clase Tienda permite manejar todas las tiendas de una Empresa, guarda el nombre de cada tienda, la cantidad de empleados
    y la venta de cada tienda durante los 3 ultimos meses
    Parameters:
        Tipo: "Electrodomésticos"
        Abierta: True
    '''
     
    tipo = "Electrodomesticos"
    abierta = True

    def __init__(self, nombre, direccion, num_empleados,ventas):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas = ventas
    
    
    def calcular_ventas_por_tienda(self):
        '''
        Método para calcular las ventas de todos los meses de la tienda instanciada
        '''
        return float(sum(self.ventas))
    
    
    def calcular_media_ventas_por_empleado(self):
        '''
        Método que calcula la media de ventas de los ultimos meses, por empleado
        '''
        return (sum(self.ventas)/(self.num_empleados))


    def mostrar_nombre_y_direccion(self):
        '''
        Método que devuelve en un string el nombre de la tienda, junto con su dirección
        '''
        mensaje = f"El nombre de la tienda es {self.nombre} y su direccion es {self.direccion}"
        return mensaje
    

    def obtener_ventas_ultimo_mes(self):
        '''
        Método que obtiene las ventas del último mes.
        '''
        return float(self.ventas[2])

   
    def dar_proyeccion_ventas(self, inversion):
        '''
        Para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. 
        Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas),
        si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta).
        El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
        '''
        for indice, valor in enumerate(self.ventas):
            if inversion < 1000:
                self.ventas[indice] = (1.2 * valor)
            else:
                self.ventas[indice] = (1.5 * valor)
        return self.ventas

# %%
tienda1 = Tienda("Tienda A", "Av. Alcala 4574",20,[4000.0,3500.0,2000.0])
tienda2 = Tienda("Tienda B", "Av. Albufera 74",11,[4500.0,2500.0,2600.0])
tienda3 = Tienda("Tienda C", "Av. tienda 474",26,[5000.0,3570.0,2800.0])
tienda4 = Tienda("Tienda Avenida2", "Av. tienda 554",26,[3200.0,3550.0,3500.0])
print(f"Tipo de la {tienda1.nombre} es {tienda1.tipo}")
print(f"Estado de la {tienda1.nombre} es {tienda1.abierta}")
print(f"Ventas de los ultimos 3 mes {tienda1.ventas}")
print(f"Total ventas de los 3 utlimos meses de la {tienda1.nombre} es {tienda1.calcular_ventas_por_tienda()}€")
print(f"La media de ventas de la {tienda1.nombre} por empleados es {tienda1.calcular_media_ventas_por_empleado()}€")
print(tienda1.mostrar_nombre_y_direccion())
print(f"Venta del ultimo mes {tienda1.obtener_ventas_ultimo_mes()}")
tienda1.dar_proyeccion_ventas(1000)
print(f"La nuevas ventas luego de la proyeccion es{tienda1.ventas}")
# Out:
# Tipo de la Tienda A es Electrodomesticos
# Estado de la Tienda A es True
# Ventas de los ultimos 3 mes [4000.0, 3500.0, 2000.0]
# Total ventas de los 3 utlimos meses de la Tienda A es 9500.0€
# La media de ventas de la Tienda A por empleados es 475.0€
# El nombre de la tienda es Tienda A y su direccion es Av. Alcala 4574
# Venta del ultimo mes 2000.0
# La nuevas ventas luego de la proyeccion es[6000.0, 5250.0, 3000.0]

# %%
#Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
tiendas = [tienda1,tienda2,tienda3,tienda4]

for tienda in tiendas:
    print(f"La venta del ultimo mes de {tienda.nombre} es --> {tienda.obtener_ventas_ultimo_mes()}€")
    
    #Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
    if "Avenida" in tienda.nombre:
        print(f"El nombre de la {tienda.nombre} contiene el string \"Avenida\"")
# Out:
# La venta del ultimo mes de Tienda A es --> 3000.0€
# La venta del ultimo mes de Tienda B es --> 2600.0€
# La venta del ultimo mes de Tienda C es --> 2800.0€
# La venta del ultimo mes de Tienda Avenida2 es --> 3500.0€
# El nombre de la Tienda Avenida2 contiene el string "Avenida"

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    '''
    Clase Perro
    Parameters:
        patas: 4
        orejas: 2
        ojos: 2
        velocidad:0 
    '''
    patas = 4
    orejas = 2
    ojos = 2
    velocidad = 0 

    def __init__(self, raza, pelo = "marron", duenio = None):
        self.raza = raza
        self.pelo = pelo
        self.duenio =duenio

    def andar(self, aumento_velocidad):
        '''
        Metodo que incrementa la velocidad de andar del perro
        '''
        self.velocidad = self.velocidad + aumento_velocidad
        return self.velocidad
    
    def parar(self):
        '''
        Metodo que pone la velocidad del perro a 0
        '''
        self.velocidad = 0
        return self.velocidad
    
    def ladrar(self,saludo):
        '''
        Metodo que recibe un argumento string y tiene como salida el texto GUAU! mas el argumento ingresado
        '''
        return print("GUAU! " + str(saludo))

# %%
perro1 = Perro("Buldog")
print(perro1.velocidad)
perro1.andar(3)
print(perro1.velocidad)
perro1.parar()
perro1.ladrar("Agua")
# Out:
# 0
# 3
# GUAU! Agua

# %%
perro2 = Perro("San Bernardo","blanco","Jose")
print(perro2.duenio)
print(perro2.ojos)
print(perro2.pelo)
print(perro2.velocidad)
perro2.andar(200)
print(perro2.velocidad)
perro2.parar()
print(perro2.velocidad)
perro2.ladrar("Comer")
# Out:
# Jose
# 2
# blanco
# 0
# 200
# 0
# GUAU! Comer

# %%
# Out:
# San Bernardo
# Marron
# None
# 0
# 2
# 4
# 0
# 'GUAU!, quiero comer'
