# %%
print("hola", sep= "", end="\n")

# %%
print("hola", sep= " ", end="Bienvennido")

# %%
def mi_funcion(a,b,/,c,d,*,e=10,f=20): #a,b son solo CONDICIONALES
    print(a,b,c,d,e,f)                #c,d posicionales o Keyword
                                      #e,f SOLO Keyword (no es obligatorio pero si quires reemplazas poner =)
# a partir del *solo keyword
mi_funcion(5,6,7,8)
mi_funcion(7,8,c=4,d=7)

# %%
print("String con 'simples")
print('String con "dobles"')
print('String con \'simples')
print("String con \"dobles\"")
# Out:
# String con 'simples
# String con "dobles"
# String con 'simples
# String con "dobles"

# %%
print("abc\\\\def")

# %%
help(input)

# %%
texto = input("Ingrese una letra")
print("Bienvenido a ", " nuestro bootcamp",sep = texto)

print("hola "," como estas", sep= "*", end="Bienvennido")

# %%
cadena = "La longitud de esta cadena es"
print(cadena,len(cadena),"y no es un float", sep = "**test**", end = " ")
print("Esto va en otra linea")

# %%
# == no es lo mismo que is
P = "HOLA"
T = "HOLA"
P is T

# %%
num1 = 5
num2 = 5.0
num1 is num2

# %%
m = ["hola"]
n = ["hola"]
print(m is n)
print(m == n)

# %%
j = ["hola"]
l = [j[0]]
print(j is l)

# %%
c = ["hola"]
d = c.copy()
print(c is d)
print(d)

# %%
if "": #vacio falso
    print("hola")

# %%
if []: #vacio falso
    print("hola")

# %%
if [[]]: #no esta vacio tiene una lista
    print("hola")

# %%
"hola amigos".split(sep= "a")
# Out:
# ['hol', ' ', 'migos']

# %%
"hola amigos".split(sep= "h")
# Out:
# ['', 'ola amigos']

# %%
" \t hola amigos".split(sep= None)
# Out:
# ['hola', 'amigos']

# %%
for x in ["a","b","c","d","e","f","g"]:
    print(x + " hi")
    print(x, end = " ")
# Out:
# a hi
# a b hi
# b c hi
# c d hi
# d e hi
# e f hi
# f g hi
# g

# %%
for m in ["a","b","c","d","c","f","c"]:
    if m in "casa":
        print(m, end= "---xxx----")
print("sigue")
# Out:
# a---xxx----c---xxx----c---xxx----c---xxx----sigue

# %%
for indice in range(len("Hola que tal")): #El texto tiene 16 caracteres
    print(indice, end= " -> ")
    print("Hola que tal"[indice])
# Out:
# 0 -> H
# 1 -> o
# 2 -> l
# 3 -> a
# 4 ->
# 5 -> q
# 6 -> u
# 7 -> e
# 8 ->
# 9 -> t
# 10 -> a
# 11 -> l

# %%
mi_cosa = [[]]
len([mi_cosa])
# Out:
# 1

# %%
len([[[]]])
# Out:
# 1

# %%
len([7,True,[4,5]])
# Out:
# 3

# %%
list(range(-5,-10,-2))
# Out:
# [-5, -7, -9]

# %%
list(range(-5,-10,2))
# Out:
# []

# %%
#help(range)

# %%
"hola"[0:2]
# Out:
# 'ho'

# %%
[0,None,5,""] [1:3]
# Out:
# [None, 5]

# %%
list(enumerate("hola"))
# Out:
# [(0, 'h'), (1, 'o'), (2, 'l'), (3, 'a')]

# %%
list(enumerate(["abc","def"]))
# Out:
# [(0, 'abc'), (1, 'def')]

# %%
mensaje = input("pon algo, exit para salir")
while (mensaje != "exit"):
    print(mensaje)
    mensaje = input("pon algo, exit para salir")
# Out:
# hi
# d
# g

# %%
for y in range(5):
    print("fila", y , "-->", end= " ")

    for x in range(5):
        print(x, end = " ")
    print()
# Out:
# fila 0 --> 0 1 2 3 4
# fila 1 --> 0 1 2 3 4
# fila 2 --> 0 1 2 3 4
# fila 3 --> 0 1 2 3 4
# fila 4 --> 0 1 2 3 4

# %%
var = list(range(6))
print(var)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
#Clase Miercoles 04/03/2026
var = list(range(7))
print(var)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
a = [4]
b = a #b apunta a la lista a

#print(type(b))
#print(b)

# %%
otra_lista = [1]
a = [otra_lista]
b = a

print(a)
print(b)
print(b[0])
# Out:
# [[1]]
# [[1]]
# [1]

# %%
otra_lista = [1]
a = [otra_lista]
b = a

del otra_lista
print(a)
print(b)
print(b[0])
# Out:
# [[1]]
# [[1]]
# [1]

# %%
otra_lista = [1]
a = [otra_lista]
b = a

del otra_lista
del a[0]
print(a)
print(b)
#print(b[0])
# Out:
# []
# []
