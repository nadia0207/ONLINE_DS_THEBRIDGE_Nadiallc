# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("¿Por qué esta magnífica tecnología cientifíca, " \
      "\n\t que ahorra trabajo y nos hace la vida mas fácil,",
      "\n\t\tnos aporta tan poca felicidad?",
      "\n\t\t\tLa respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino",
      '\n"Albert Einstein"')
# Out:
# ¿Por qué esta magnífica tecnología cientifíca,
# 	 que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
direcc = "Castellana"
num_direcc = 24
poblacion = "Madrid"
cod_postal = 26774
concat = direcc + " " + str(num_direcc) + " " + poblacion + " " + str(cod_postal)
print(concat)
# Out:
# Castellana 24 Madrid 26774

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
direcc = "Castellana"
num_direcc = "24"
poblacion = "Madrid"
cod_postal = "26774"
print(direcc , num_direcc, poblacion, cod_postal)
# Out:
# Castellana 24 Madrid 26774

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %% [markdown]
# 1. 81mi_variable = "Agua"
# 2. True = "Ejercicio"
# 3. mi variab1e = "Alpha"
# 4. exec = True
# 5. import = 40
# 6. otra_var = "Ejercicio
# 7.
# 8.

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
celsius = float(input("Ingrese grados Celsius a convertir"))
fahrenheit = (celsius*9/5) + 32
print(f"{celsius} celsius es equivalente a {fahrenheit} Fahrenheit")
# Out:
# 7.0 celsius es equivalente a 44.6 Fahrenheit

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
celsius = float(input("Ingrese grados Celsius a convertir")) #Guardo celius solicitado en imput
fahrenheit = (celsius*9/5) + 32 #empleando formula
print(f"{celsius} celsius es equivalente a {fahrenheit} Fahrenheit") #Imprimiendo resultado
# Out:
# 100.0 celsius es equivalente a 212.0 Fahrenheit
