# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
num1 = 10
num2 = 15.4
#Comprobando sus tipos
print(num1,type(num1))
print(num2,type(num2))

suma = num1 + num2
print(suma,type(suma))

#Eliminar las dos primeras variables creadas
del num1
del num2
# Out:
# 10 <class 'int'>
# 15.4 <class 'float'>
# 25.4 <class 'float'>

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math
grados = float(input("Ingrese los grados radianes"))
radianes = round(grados*(math.pi/180),2)
print(f"{grados} grados es equivalente a {radianes} radianes")
# Out:
# 200.0 grados es equivalente a 3.49 radianes

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
#Solicitar se ingrese un base y altura
base = float(input("Ingrese base del paralelogramo"))
altura = float(input("Ingrese altura del paralelogramo"))
print("El Area del paralelogramo es: ", base * altura)
# Out:
# El Area del paralelogramo es:  30.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1
#Si A y B son equivalentes
print(A == B)
#2. Si A y C NO son equivalentes
print(A != C)
#3. Si A es mayor que C 
print(A > C)
#4. Si C es menor o igual que A
print(C <= A)
#5. Si B NO es equivalente a C
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
texto1 = input("Ingrese primer texto").upper()
texto2 = input("Ingrese otro texto").upper()
print("¿Ambos textos son equivalentes?", texto1 == texto2)
# Out:
# ¿Ambos textos son equivalentes? False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
texto3 = input("Ingrese primer texto")
texto4 = input("Ingrese segundo texto")
texto5 = input("Ingrese tercer texto")
print("Todos son iguales: ", texto3 == texto4 and texto3 == texto5 and texto4 == texto5)
print("Al menos 2 son iguales: ", texto3 == texto4 or texto3 == texto5 or texto4 == texto5)
# Out:
# Todos son iguales:  False
# Al menos 2 son iguales:  True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
numero1 = float(input("Ingrese primer numero"))
numero2 = float(input("Ingrese segundo numero"))
suma = numero1 + numero2
print("La suma es y es mayor que 10:", suma > 10)
print("La suma es y es menor que 10:", suma < 10)
print("La suma es y es igual que 10", suma == 10)
# Out:
# La suma es y es mayor que 10: False
# La suma es y es menor que 10: True
# La suma es y es igual que 10 False

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. False
# 2. False
# 3. False
# 4. False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
Lista_num = [4, 6, 8, -1]
#Calcula el máximo de la lista: [4, 6, 8, -1]
print("Maximo numero de la Lista", max(Lista_num))

#Suma todos los elementos de la lista anterior
print("La suma de todos los elementos de la lista es", sum(Lista_num))

#Redondea este float a 3 dígitos decimales: 63.45125696
print("Redondear 63.45125696 a 3 decimales", round(63.45125696,3) )

#Valor absoluto de: -74
print("Valor absoluto de -74 es", abs(-74))
# Out:
# Maximo numero de la Lista 8
# La suma de todos los elementos de la lista es 17
# Redondear 63.45125696 a 3 decimales 63.451
# Valor absoluto de -74 es 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
texto = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#Texto todo a mayúsculas
print(texto.upper())

#Texto todo a minúsculas
print(texto.lower())

#Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
print(texto.title())

#Crea una lista dividiéndolo por sus espacios
letra = texto.split(" ")
print(letra)

#Sustituye las comas `,` por puntos y comas `;`
print(texto.replace(",",";"))

#Elimina las `a` minúsculas
print(texto.replace("a",""))
# Out:
# EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.
# en un lugar de la mancha, de cuyo nombre no quiero acordarme.
# En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.
# ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme.']
# En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
#Crea una lista con 3 elementos numéricos
mi_lista = [4,5,1]

#Añade un cuarto elemento
mi_lista.append(8)
print(mi_lista)

#Calcula la suma de todos
suma_lista = sum(mi_lista)
print(suma_lista)

#Elimina el segundo elemento de la lista
mi_lista.pop(1)
print(mi_lista)

#Añade otro elemento en la posicion 3 de la lista
mi_lista.insert(3,10)
print(mi_lista)

#Crea otra lista con 4 elementos y concaténala a la que ya tenías.
otra_lista = [12,8,16,20]
nueva_lista = mi_lista + otra_lista
print(nueva_lista)
# Out:
# [4, 5, 1, 8]
# 18
# [4, 1, 8]
# [4, 1, 8, 10]
# [4, 1, 8, 10, 12, 8, 16, 20]
