# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 4:
# ## Funciones, métodos, listas

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 1
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista = [4, 6, 8, -1]

#Calcula el máximo de la lista: [4, 6, 8, -1]
print("Número màximo de la Lista",max(lista))

#Suma todos los elementos de la lista anterior
print("Suma de valores de la Lista",sum(lista))

#Redondea este float a 3 dígitos decimales: 63.451256965
numero = 63.451256965
print("Redondeo de un número",round(numero,3))

#Valor absoluto de: -74
print("Valor absoluto de un número -74 es",abs(-74))
# Out:
# Número màximo de la Lista 8
# Suma de valores de la Lista 17
# Redondeo de un número 63.451
# Valor absoluto de un número -74 es 74

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
texto = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."

#Pásalo todo a mayúsculas
print(texto.upper())

#Pásalo todo a minúsculas
print(texto.lower())

#Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
print(texto.title())

#Crea una lista dividiéndolo por sus espacios
letras = texto.split()
print(letras)

#Sustituye las comas , por puntos y comas ;
print(texto.replace(',',';'))

#Elimina las a minúsculas
print(texto.replace('a',''))
# Out:
# EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.
# en un lugar de la mancha, de cuyo nombre no quiero acordarme.
# En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.
# ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme.']
# En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.
# 7. Ordena la lista de menor a mayor.
# 8. BONUS: Ordena la lista de mayor a menor.
# (*PISTA: Para hacer 8, tendrás que buscar en la información del método...*)
#
#
# NOTA: Pinta por pantalla el resultado de cada paso.

# %%
#Crea una lista con 3 elementos numéricos
lista_1 = [2,3,4]
print(lista_1)

#Añade un cuarto elemento
lista_1.append(5)
print(lista_1)

#Calcula la suma de todos
suma = sum(lista_1)
print(suma)

#Elimina el segundo elemento de la lista
lista_1.pop(1)
print(lista_1)

#Añade otro elemento en la posicion 3 de la lista
lista_1.insert(3,0)
print(lista_1)

#Crea otra lista con 4 elementos y concaténala a la que ya tenías.
lista_2 = [1,2,3,4]
lista_3 = lista_1 + lista_2
print(lista_3)

#Ordena la lista de menor a mayor.
lista_3.sort()
print(lista_3)


#BONUS: Ordena la lista de mayor a menor.
lista_3.sort(reverse=True)
print(lista_3)
# Out:
# [2, 3, 4]
# [2, 3, 4, 5]
# 14
# [2, 4, 5]
# [2, 4, 5, 0]
# [2, 4, 5, 0, 1, 2, 3, 4]
# [0, 1, 2, 2, 3, 4, 4, 5]
# [5, 4, 4, 3, 2, 2, 1, 0]
